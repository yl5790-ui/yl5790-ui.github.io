# %% [markdown]
# # Project 1 — NYPD Shooting Incident Data (2019)
#
# This project analyzes the 2019 NYPD shooting incident data to explore where and when incidents occurred, and basic victim/perpetrator demographics.
# Data source: NYC Open Data (NYPD Shooting Incident Data, 2019).
