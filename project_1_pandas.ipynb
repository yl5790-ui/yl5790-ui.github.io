# %% [markdown]
# # Project 1 — NYPD Shooting Incident Data (2019)
#
# This notebook uses the NYPD Shooting Incident Data (2019) to calculate basic descriptive statistics (mean, median, mode) using **pandas**.

# %%
import pandas as pd

df = pd.read_csv("nypd_shootings_2019.csv")

print("Columns:", df.columns.tolist())

numeric_col = "PRECINCT"  

data = df[numeric_col].dropna()

mean_pandas = data.mean()
median_pandas = data.median()
mode_pandas = data.mode()[0]

print("📊 Pandas Results:")
print(f"Mean: {mean_pandas:.2f}")
print(f"Median: {median_pandas:.2f}")
print(f"Mode: {mode_pandas:.2f}")
# Out:
# Columns: ['INCIDENT_KEY', 'OCCUR_DATE', 'OCCUR_TIME', 'BORO', 'PRECINCT', 'JURISDICTION_CODE', 'LOCATION_DESC', 'STATISTICAL_MURDER_FLAG', 'PERP_AGE_GROUP', 'PERP_SEX', 'PERP_RACE', 'VIC_AGE_GROUP', 'VIC_SEX', 'VIC_RACE', 'X_COORD_CD', 'Y_COORD_CD', 'Latitude', 'Longitude']
# 📊 Pandas Results:
# Mean: 65.68
# Median: 69.00
# Mode: 75.00

# %%
print("\n📈 NYPD Shootings by Precinct (approximate counts):")

precinct_counts = data.value_counts().sort_index()

for precinct, count in precinct_counts.items():
    print(f"Precinct {int(precinct):3}: {'*' * (count // 10)} ({count})")
# Out:
# 📈 NYPD Shootings by Precinct (approximate counts):
# Precinct   1:  (2)
# Precinct   5:  (3)
# Precinct   7:  (4)
# Precinct   9:  (5)
# Precinct  10:  (3)
# Precinct  13:  (2)
# Precinct  17:  (1)
# Precinct  18:  (1)
# Precinct  19:  (1)
# Precinct  20:  (2)
# Precinct  23: *** (33)
# Precinct  24:  (1)
# Precinct  25: * (17)
# Precinct  26:  (3)
# Precinct  28: * (14)
# Precinct  30:  (7)
# Precinct  32: * (19)
# Precinct  33: * (10)
# Precinct  34: * (17)
# Precinct  40: *** (32)
# Precinct  41: * (17)
# Precinct  42: *** (37)
# Precinct  43: * (16)
# Precinct  44: *** (34)
# Precinct  45:  (9)
# Precinct  46: *** (37)
# Precinct  47: ** (25)
# Precinct  48: ** (22)
# Precinct  49: * (15)
# Precinct  50:  (4)
# Precinct  52: * (18)
# Precinct  60: * (18)
# Precinct  61:  (3)
# Precinct  62:  (4)
# Precinct  63: * (10)
# Precinct  67: *** (33)
# Precinct  69: * (13)
# Precinct  70: * (15)
# Precinct  71: * (14)
# Precinct  72:  (4)
# Precinct  73: **** (48)
# Precinct  75: ****** (66)
# Precinct  77: **** (43)
# Precinct  78:  (1)
# Precinct  79: *** (32)
# Precinct  81: *** (30)
# Precinct  83: * (14)
# Precinct  84:  (6)
# Precinct  88:  (9)
# Precinct  90:  (7)
# Precinct  94:  (2)
# Precinct 100:  (3)
# Precinct 101: * (15)
# Precinct 102: * (10)
# Precinct 103: * (13)
# Precinct 104:  (1)
# Precinct 105: * (18)
# Precinct 106:  (5)
# Precinct 107:  (2)
# Precinct 108:  (5)
# Precinct 109: * (10)
# Precinct 110:  (7)
# Precinct 112:  (2)
# Precinct 113: *** (37)
# Precinct 114: ** (22)
# Precinct 115:  (8)
# Precinct 120: * (12)
# Precinct 121:  (7)
# Precinct 122:  (6)
# Precinct 123:  (1)
